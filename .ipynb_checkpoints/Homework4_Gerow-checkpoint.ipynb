# %%
# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# OS
import os

# Math
import numpy as np

# Paths
path = './data/'
pathout = './data/'
pathgraphs = './graphs/'

for p in [path, pathout, pathgraphs]:
    if os.path.exists(p)==False:
        os.mkdir(p)

# %% [markdown]
# Exercise 1: Write a function that computes the level of output generated by a constant returns to scale Cobb-Douglas production function, i.e., such that it computes  𝐴⋅𝐾𝛼⋅𝐿1−𝛼 .

# %%
def my_CobbDouglas(K=1, L=1, A=1, alpha=0.3):
    '''
    This function computes the level of output of a Cobb-Douglas production function.
    Given values of K, L, A, and alpha it returns $A\cdot K^\alpha \cdot L^{1-\alpha}$.
    Parameters:
    -----------
    K: float, integer or any other number, default=1
    L: float, integer or any other number, default=1
    A: float, integer or any other number, default=1
    alpha: float between (0,1), default=0.3
    
    Returns:
    --------
    out = A * K**alpha * L**(1-alpha)
    
    Example:
    >>> out = CobbDouglas(4, 9, 2, 1/2)
    >>> out
        12
    '''
    return A * K**alpha * L**(1-alpha)

# %%
my_CobbDouglas(1,1,1,.3)
# Out:
# 1.0

# %%
my_CobbDouglas(4,9,2,.5)
# Out:
# 12.0

# %%
K = np.linspace(0, 5, 100)
print(K)
# Out:
# [0.         0.05050505 0.1010101  0.15151515 0.2020202  0.25252525
#  0.3030303  0.35353535 0.4040404  0.45454545 0.50505051 0.55555556
#  0.60606061 0.65656566 0.70707071 0.75757576 0.80808081 0.85858586
#  0.90909091 0.95959596 1.01010101 1.06060606 1.11111111 1.16161616
#  1.21212121 1.26262626 1.31313131 1.36363636 1.41414141 1.46464646
#  1.51515152 1.56565657 1.61616162 1.66666667 1.71717172 1.76767677
#  1.81818182 1.86868687 1.91919192 1.96969697 2.02020202 2.07070707
#  2.12121212 2.17171717 2.22222222 2.27272727 2.32323232 2.37373737
#  2.42424242 2.47474747 2.52525253 2.57575758 2.62626263 2.67676768
#  2.72727273 2.77777778 2.82828283 2.87878788 2.92929293 2.97979798
#  3.03030303 3.08080808 3.13131313 3.18181818 3.23232323 3.28282828
#  3.33333333 3.38383838 3.43434343 3.48484848 3.53535354 3.58585859
#  3.63636364 3.68686869 3.73737374 3.78787879 3.83838384 3.88888889
#  3.93939394 3.98989899 4.04040404 4.09090909 4.14141414 4.19191919
# ...

# %% [markdown]
# Exercise 2: Use the function you created and plot the production function as a function of  𝐾  for given values of  𝐴  and  𝐿 . Hint: Use the np.linspace(0, 5, 100) function to create an array of values of  𝐾  with 100 point between 0 and 5.

# %%
x = my_CobbDouglas(K)
plt.plot(x, c='r', marker='o', markersize=4, linestyle='-')
plt.xlabel(r'input', fontsize=18)
plt.ylabel(r'output', fontsize=18)
plt.title(r'Cobb Douglas Graph', fontsize=24)
plt.legend(fontsize=18)
plt.savefig('Exercise2.png')
plt.savefig('Exercise2.pdf')
plt.savefig('Exercise2.jpeg')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Exercise 3: Show with a plot the effect of increasing  𝐴  from 1 to 2, 4, or 5.

# %%
x2 = my_CobbDouglas(K,A=5)
plt.plot(x2, c='r', marker='o', markersize=4, linestyle='-')
plt.xlabel(r'input', fontsize=18)
plt.ylabel(r'output', fontsize=18)
plt.title(r'Cobb Douglas Graph', fontsize=24)
plt.legend(fontsize=18)
plt.savefig('Exercise3.png')
plt.savefig('Exercise3.pdf')
plt.savefig('Exercise3.jpeg')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Exercise 4: Show with a plot the effect of increasing  𝐿  from 1 to 2, 4, 5.

# %%
x3 = my_CobbDouglas(K,L=5)
plt.plot(x3, c='r', marker='o', markersize=4, linestyle='-')
plt.xlabel(r'input', fontsize=18)
plt.ylabel(r'output', fontsize=18)
plt.title(r'Cobb Douglas Graph', fontsize=24)
plt.legend(fontsize=18)
plt.savefig('Exercise4.png')
plt.savefig('Exercise4.pdf')
plt.savefig('Exercise4.jpeg')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Exercise 5: Save the previous plots into png, jpeg, and pdf files using the plt.savefig function.
